# %% [markdown]
# #Get Data from the txt files and store them in an array

# %% [markdown]
# ##First Dataset

# %%
import pandas as pd

# %%
cdf = pd.read_csv("/content/drive/MyDrive/cbert raw dataset/output.csv")

cdf.head()
# Out:
#                                                  set  \
# 0   paniguradong matutuwa siya sigurado malipay siya
# 1  puso niyay puno nang kaligayahan ang iyang kas...
# 2                          ilan kulay pila nag kolor
# 3          nakakapagbasa ingles makabasa og iningles
# 4                  nakikita mata mo nakita nako mata
#
#                             Filipino  \
# 0       'paniguradong matutuwa siya'
# 1  puso niya'y puno nang kaligayahan
# 2                       'ilan kulay'
# 3             'nakakapagbasa ingles'
# 4                 'nakikita mata mo'
#
#                                            Cebuano  \
# 0                          'sigurado malipay siya'
# 1  'ang iyang kasingkasing napuno hingpit kalipay'
# 2                                 'pila nag kolor'
# 3                        'makabasa ko og iningles'
# 4                               'nakita nako mata'
#
#                                            tokenized
# ...

# %%
len(cdf)
# Out:
# 105252

# %%
#create array for the labels for the df dataset
label0 = []
for i in range(len(cdf)):
  label0.append("df")

len(label0)
# Out:
# 105252

# %%
df = pd.DataFrame()
df['text'] = cdf['Cebuano']
df['source'] = label0
df.head()
# Out:
#                                               text source
# 0                          'sigurado malipay siya'     df
# 1  'ang iyang kasingkasing napuno hingpit kalipay'     df
# 2                                 'pila nag kolor'     df
# 3                        'makabasa ko og iningles'     df
# 4                               'nakita nako mata'     df

# %%
df
# Out:
#                                                      text source
# 0                                 'sigurado malipay siya'     df
# 1         'ang iyang kasingkasing napuno hingpit kalipay'     df
# 2                                        'pila nag kolor'     df
# 3                               'makabasa ko og iningles'     df
# 4                                      'nakita nako mata'     df
# ...                                                   ...    ...
# 105247  'tungod nahadlok angkonon sayup labi pang daot...     df
# 105248  'dili gusto angkonon sayup naa gitawag state o...     df
# 105249  'tungod gibati pagkatao kaakuhan mahubad pagan...     df
# 105250  lahat tayo ay makasalanan', 'apan tinuod, maka...     df
# 105251  'mao matag higayon magampo maghangyo dios alan...     df
#
# [105252 rows x 2 columns]

# %% [markdown]
# DF0 Initial Values = 105252

# %%
len(df)
# Out:
# 105252

# %%
orig0 = len(df)

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 103378

# %%
df.head()
# Out:
#                                               text source
# 0                          'sigurado malipay siya'     df
# 1  'ang iyang kasingkasing napuno hingpit kalipay'     df
# 2                                 'pila nag kolor'     df
# 3                        'makabasa ko og iningles'     df
# 4                               'nakita nako mata'     df

# %% [markdown]
# ##Second Dataset

# %%
import re

# %%
# Read the txt file into a DataFrame
df1 = pd.DataFrame()
df1['text'] = pd.read_table("/content/drive/MyDrive/cbert raw dataset/ceb_instructions_dataset.txt",header=None)

# Print the DataFrame
df1
# Out:
#                                                     text
# 0         Paghimo og putahe gamit lamang ang mga utanon.
# 1       Pagsulat ug sentence bahin sa artikulo gamit ...
# 2      Paghimo og listahan sa mga benepisyo sa pangla...
# 3                  Paghimo ug story nga corny ug cheesy.
# 4       Ihulagway ang lima ka yugto sa paghunahuna sa...
# ...                                                  ...
# 62076   Ilista ang tanan nga posible nga mga numero g...
# 62077  Ilha ang tono sa mosunod nga pahayag: "Dili ko...
# 62078  Paghimo usa ka pagsusi sa sine alang sa "Aveng...
# 62079   Ipatin-aw ang kalainan tali sa homophones "di...
# 62080   Pagsulat og sulat pasalamat ngadto sa usa ka ...
#
# [62081 rows x 1 columns]

# %%
len(df1)
# Out:
# 62081

# %%
orig1 = len(df1)

# %%
label1 = []
for i in range(len(df1)):
  label1.append('df1')

# %%
len(label1)
# Out:
# 62081

# %%
df1['source'] = label1
df1
# Out:
#                                                     text source
# 0         Paghimo og putahe gamit lamang ang mga utanon.    df1
# 1       Pagsulat ug sentence bahin sa artikulo gamit ...    df1
# 2      Paghimo og listahan sa mga benepisyo sa pangla...    df1
# 3                  Paghimo ug story nga corny ug cheesy.    df1
# 4       Ihulagway ang lima ka yugto sa paghunahuna sa...    df1
# ...                                                  ...    ...
# 62076   Ilista ang tanan nga posible nga mga numero g...    df1
# 62077  Ilha ang tono sa mosunod nga pahayag: "Dili ko...    df1
# 62078  Paghimo usa ka pagsusi sa sine alang sa "Aveng...    df1
# 62079   Ipatin-aw ang kalainan tali sa homophones "di...    df1
# 62080   Pagsulat og sulat pasalamat ngadto sa usa ka ...    df1
#
# [62081 rows x 2 columns]

# %%
df1 = df1.drop_duplicates()
len(df1)
# Out:
# 62076

# %%
df1
# Out:
#                                                     text source
# 0         Paghimo og putahe gamit lamang ang mga utanon.    df1
# 1       Pagsulat ug sentence bahin sa artikulo gamit ...    df1
# 2      Paghimo og listahan sa mga benepisyo sa pangla...    df1
# 3                  Paghimo ug story nga corny ug cheesy.    df1
# 4       Ihulagway ang lima ka yugto sa paghunahuna sa...    df1
# ...                                                  ...    ...
# 62076   Ilista ang tanan nga posible nga mga numero g...    df1
# 62077  Ilha ang tono sa mosunod nga pahayag: "Dili ko...    df1
# 62078  Paghimo usa ka pagsusi sa sine alang sa "Aveng...    df1
# 62079   Ipatin-aw ang kalainan tali sa homophones "di...    df1
# 62080   Pagsulat og sulat pasalamat ngadto sa usa ka ...    df1
#
# [62076 rows x 2 columns]

# %% [markdown]
# ##Third Dataset

# %%
#df = pd.read_csv(csvfile, header = None, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8')
f = open("/content/drive/MyDrive/cbert raw dataset/cleaned_Bible.txt", "r")
print(len(f.read()))
f.close()
# Out:
# 3950401

# %%
ceb_bible = []
f = open("/content/drive/MyDrive/cbert raw dataset/cleaned_Bible.txt", "r")
for line in f:
  ceb_bible.append(line.strip())
f.close()

# %%
len(ceb_bible)
# Out:
# 23515

# %%
orig2 = len(ceb_bible)

# %%
df2 = pd.DataFrame()
df2['text'] = pd.DataFrame(ceb_bible)
df2
# Out:
#                                                     text
# 0      Sa sinugdan gibuhat sa Dios ang mga langit ug ...
# 1      Ug ang yuta awa-aw ug walay sulod; ug ang kang...
# 2      Ug miingon ang Dios: Mahimo ang kahayag: ug di...
# 3      Ug nakita sa Dios ang kahayag nga kini maayo; ...
# 4      Ug gihinganlan sa Dios ang kahayag nga Adlaw, ...
# ...                                                  ...
# 23510  Ug si Jesus, sa pagkamatikud niya niini, mipah...
# 23511  ug iyang gipina-han sila nga dili nila siya ip...
# 23512  Kini tuman sa gisulti pinaagi sa profeta nga s...
# 23513  "Tan-awa, ang sulogoon ko nga akong pinili, an...
# 23514  Dili siya magapakiglalis, ni magasinggit, ug w...
#
# [23515 rows x 1 columns]

# %%
label2 = []
for i in range(len(df2)):
  label2.append('df2')

# %%
df2['source'] = label2
df2
# Out:
#                                                     text source
# 0      Sa sinugdan gibuhat sa Dios ang mga langit ug ...    df2
# 1      Ug ang yuta awa-aw ug walay sulod; ug ang kang...    df2
# 2      Ug miingon ang Dios: Mahimo ang kahayag: ug di...    df2
# 3      Ug nakita sa Dios ang kahayag nga kini maayo; ...    df2
# 4      Ug gihinganlan sa Dios ang kahayag nga Adlaw, ...    df2
# ...                                                  ...    ...
# 23510  Ug si Jesus, sa pagkamatikud niya niini, mipah...    df2
# 23511  ug iyang gipina-han sila nga dili nila siya ip...    df2
# 23512  Kini tuman sa gisulti pinaagi sa profeta nga s...    df2
# 23513  "Tan-awa, ang sulogoon ko nga akong pinili, an...    df2
# 23514  Dili siya magapakiglalis, ni magasinggit, ug w...    df2
#
# [23515 rows x 2 columns]

# %%
df2.tail(5)
# Out:
#                                                     text source
# 23510  Ug si Jesus, sa pagkamatikud niya niini, mipah...    df2
# 23511  ug iyang gipina-han sila nga dili nila siya ip...    df2
# 23512  Kini tuman sa gisulti pinaagi sa profeta nga s...    df2
# 23513  "Tan-awa, ang sulogoon ko nga akong pinili, an...    df2
# 23514  Dili siya magapakiglalis, ni magasinggit, ug w...    df2

# %%
len(df2)
# Out:
# 23515

# %%
df2 = df2.drop_duplicates()
len(df2)
# Out:
# 23296

# %%
df2
# Out:
#                                                     text source
# 0      Sa sinugdan gibuhat sa Dios ang mga langit ug ...    df2
# 1      Ug ang yuta awa-aw ug walay sulod; ug ang kang...    df2
# 2      Ug miingon ang Dios: Mahimo ang kahayag: ug di...    df2
# 3      Ug nakita sa Dios ang kahayag nga kini maayo; ...    df2
# 4      Ug gihinganlan sa Dios ang kahayag nga Adlaw, ...    df2
# ...                                                  ...    ...
# 23510  Ug si Jesus, sa pagkamatikud niya niini, mipah...    df2
# 23511  ug iyang gipina-han sila nga dili nila siya ip...    df2
# 23512  Kini tuman sa gisulti pinaagi sa profeta nga s...    df2
# 23513  "Tan-awa, ang sulogoon ko nga akong pinili, an...    df2
# 23514  Dili siya magapakiglalis, ni magasinggit, ug w...    df2
#
# [23296 rows x 2 columns]

# %% [markdown]
# ##4th Dataset

# %%
df3 = pd.DataFrame()
df3['text'] = pd.read_table("/content/drive/MyDrive/cbert raw dataset/panzo_ceb_dataset.txt",header=None)
df3
# Out:
#                                                    text
# 0     Apan, sa Hunyo 1956, nasulayan ang mga saad ni...
# 1     Alang niana, kinahanglan nila wagtangon ang mg...
# 2     Kapin sa upat ka milyong mga tawo ang nangadto...
# 3     Siguroha nga ang ahente nga magtabang nimo og ...
# 4     Ang pag-blog usab "magpugos sa mga estudyante ...
# ...                                                 ...
# 3979  Ang paggamit og barko sa pagkarga og mga produ...
# 3980  Sa tinuod, ang 35 milimetrong format kay, medy...
# 3981  Sa ulahi, napalong sa mga kabumberohan ang sun...
# 3982  Si bisan kinsa nga nagplanong mobisita sa naso...
# 3983  Ang satellite gipadala ngadto sa kawanangan pi...
#
# [3984 rows x 1 columns]

# %%
len(df3)
# Out:
# 3984

# %%
orig3 = len(df3)

# %%
label3 = []
for i in range(len(df3)):
  label3.append('df3')
len(label3)
# Out:
# 3984

# %%
df3['source'] = label3
df3
# Out:
#                                                    text source
# 0     Apan, sa Hunyo 1956, nasulayan ang mga saad ni...    df3
# 1     Alang niana, kinahanglan nila wagtangon ang mg...    df3
# 2     Kapin sa upat ka milyong mga tawo ang nangadto...    df3
# 3     Siguroha nga ang ahente nga magtabang nimo og ...    df3
# 4     Ang pag-blog usab "magpugos sa mga estudyante ...    df3
# ...                                                 ...    ...
# 3979  Ang paggamit og barko sa pagkarga og mga produ...    df3
# 3980  Sa tinuod, ang 35 milimetrong format kay, medy...    df3
# 3981  Sa ulahi, napalong sa mga kabumberohan ang sun...    df3
# 3982  Si bisan kinsa nga nagplanong mobisita sa naso...    df3
# 3983  Ang satellite gipadala ngadto sa kawanangan pi...    df3
#
# [3984 rows x 2 columns]

# %%
df3 = df3.drop_duplicates()

# %%
len(df3)
# Out:
# 1933

# %% [markdown]
# ##5th Dataset

# %%
ceb_lit = []

f = open("/content/drive/MyDrive/cbert raw dataset/raw_ceb_poems_and_stories.txt", "r")
for line in f:
  ceb_lit.append(line.strip())
f.close()

# %%
len(ceb_lit)
# Out:
# 608

# %%
df4 = pd.DataFrame()
df4['text'] = pd.DataFrame(ceb_lit)
df4
# Out:
#                                                   text
# 0    kaniadto, miingon si Nanay,“kanunay, ayaw gyo’...
# 1    sa di dugay,miabi ang akong mga mata,mibukhad ...
# 2    sa dihadiha miduol akogihangop, gidawat ang pa...
# 3    subay ning sandayong midagayday ang tubig gika...
# 4    diin giugbok mo ang talinggab sa patong nga ka...
# ..                                                 ...
# 603  Pag-abli nako, wala nay sulod ang safe. Nakata...
# 604  Mohawa na unta ko, apan samag kuryoso nga bata...
# 605  Mga notes kini mahitungod sa kang Uncle sab ng...
# 606  Sa ilawom aning mga notes ang way kataposang s...
# 607  Nahimuot ko nga ang bida kay gipangalan niya n...
#
# [608 rows x 1 columns]

# %%
len(df4)
# Out:
# 608

# %%
orig4 = len(df4)

# %%
label4 = []
for i in range(len(df4)):
  label4.append('df4')
len(label4)
# Out:
# 608

# %%
df4['source'] = label4
df4
# Out:
#                                                   text source
# 0    kaniadto, miingon si Nanay,“kanunay, ayaw gyo’...    df4
# 1    sa di dugay,miabi ang akong mga mata,mibukhad ...    df4
# 2    sa dihadiha miduol akogihangop, gidawat ang pa...    df4
# 3    subay ning sandayong midagayday ang tubig gika...    df4
# 4    diin giugbok mo ang talinggab sa patong nga ka...    df4
# ..                                                 ...    ...
# 603  Pag-abli nako, wala nay sulod ang safe. Nakata...    df4
# 604  Mohawa na unta ko, apan samag kuryoso nga bata...    df4
# 605  Mga notes kini mahitungod sa kang Uncle sab ng...    df4
# 606  Sa ilawom aning mga notes ang way kataposang s...    df4
# 607  Nahimuot ko nga ang bida kay gipangalan niya n...    df4
#
# [608 rows x 2 columns]

# %%
df4 = df4.drop_duplicates()
len(df4)
# Out:
# 348

# %% [markdown]
# ##6th Dataset

# %%
df5 = pd.DataFrame()
df5['text'] = pd.read_table("/content/drive/MyDrive/cbert raw dataset/translate_cebdataset.txt",header=None)
df5
# Out:
#                                                      text
# 0                            Ako maayo, salamat, ug ikaw?
# 1                       Nagkahinanglan kami og igsasagwat
# 2                                                  Morado
# 3                                                 Tugpaan
# 4                                      Halili sa kuryente
# ...                                                   ...
# 102788  Ako, si Jesus, mao ang nagpadala kaninyo sa ak...
# 102789  Ang Espiritu ug ang Pangasaw-onon nagaingon, "...
# 102790  Akong pasidan-an ang tanang magapatalinghug sa...
# 102791  Ug kon adunay magataktak ug mga pulong gikan s...
# 102792  Ang nagapanghimatuod mahitungod niining mga bu...
#
# [102793 rows x 1 columns]

# %%
len(df5)
# Out:
# 102793

# %%
orig5 = len(df5)

# %%
label5 = []
for i in range(len(df5)):
  label5.append('df5')
len(label5)
# Out:
# 102793

# %%
df5['source'] = label5
df5
# Out:
#                                                      text source
# 0                            Ako maayo, salamat, ug ikaw?    df5
# 1                       Nagkahinanglan kami og igsasagwat    df5
# 2                                                  Morado    df5
# 3                                                 Tugpaan    df5
# 4                                      Halili sa kuryente    df5
# ...                                                   ...    ...
# 102788  Ako, si Jesus, mao ang nagpadala kaninyo sa ak...    df5
# 102789  Ang Espiritu ug ang Pangasaw-onon nagaingon, "...    df5
# 102790  Akong pasidan-an ang tanang magapatalinghug sa...    df5
# 102791  Ug kon adunay magataktak ug mga pulong gikan s...    df5
# 102792  Ang nagapanghimatuod mahitungod niining mga bu...    df5
#
# [102793 rows x 2 columns]

# %%
df5 = df5.drop_duplicates()
len(df5)
# Out:
# 82752

# %% [markdown]
# ##7th Dataset

# %%
sunstar_dat = []

f = open("/content/drive/MyDrive/cbert raw dataset/sunstar.txt", "r")
for line in f:
  sunstar_dat.append(line.strip())
f.close()

# %%
df6 = pd.DataFrame()
df6['text'] = pd.DataFrame(sunstar_dat)
df6
# Out:
#                                                    text
# 0     Gitanggong karon sa Carbon Police Station ang ...
# 1     Dihang wa nakahatag og igong rason nganong kuy...
# 2     Hugot nga gipanghimakak ni Ken nga duna siyay ...
# 3     Matod niya, lima ka tuig na siya nga nagbalik-...
# 4     Nakurat na lang siya nga gi-hold sila diha sa ...
# ...                                                 ...
# 3095  Gani, usa sa mga tubod mobugwak ug yellow nga ...
# 3096  Bugtong ang tubod nga nadiskubrehan sa Alang-a...
# 3097  Nasuta ning mantalaan gi­kan ni Barlam nga nag...
# 3098  Dugang niya nga gipahibalo na sab nila niini a...
# 3099  Sumala ni Barlam nga di mahimong makuhaan ug s...
#
# [3100 rows x 1 columns]

# %%
len(df6)
# Out:
# 3100

# %%
orig6 = len(df6)

# %%
label6 = []
for i in range(len(df6)):
  label6.append('df6')
len(label6)
# Out:
# 3100

# %%
df6['source'] = label6
df6
# Out:
#                                                    text source
# 0     Gitanggong karon sa Carbon Police Station ang ...    df6
# 1     Dihang wa nakahatag og igong rason nganong kuy...    df6
# 2     Hugot nga gipanghimakak ni Ken nga duna siyay ...    df6
# 3     Matod niya, lima ka tuig na siya nga nagbalik-...    df6
# 4     Nakurat na lang siya nga gi-hold sila diha sa ...    df6
# ...                                                 ...    ...
# 3095  Gani, usa sa mga tubod mobugwak ug yellow nga ...    df6
# 3096  Bugtong ang tubod nga nadiskubrehan sa Alang-a...    df6
# 3097  Nasuta ning mantalaan gi­kan ni Barlam nga nag...    df6
# 3098  Dugang niya nga gipahibalo na sab nila niini a...    df6
# 3099  Sumala ni Barlam nga di mahimong makuhaan ug s...    df6
#
# [3100 rows x 2 columns]

# %%
df6 = df6.drop_duplicates()
len(df6)
# Out:
# 3094

# %% [markdown]
# ##8th Dataset

# %%
df7 = pd.DataFrame()
df7['text'] = pd.read_csv("/content/drive/MyDrive/cbert raw dataset/yes-bisaya.csv")
df7
# Out:
#                                                    text
# 0     Aduna'y pagsaka sa presyo sa lana, epektibo sa...
# 1     MOTORISTA, PATAY HUMAN MALIGSAN ANG ULO SA 10-...
# 2     9 KA MAYOR SA NEGOR, NANAWAGAN NGA I-POSTPONE ...
# 3     LALAKI SA INDIA, NIPUYO OG DUL-AN 2 KA TUIG SA...
# 4     Mao kini ang hulagyway ni President Ferdinand ...
# ...                                                 ...
# 1153  SENADOR PARA\nSA MGA TRABAHADOR\n“Dungan sa pa...
# 1154  Kanang card nga malipay kang wala jud nimo nag...
# 1155  Nawaan og trabaho\nHATAGA'G PUHUNAN SA NEGOSYO...
# 1156  Loren Loves Isabela \nSa pagbisita sa mga bolu...
# 1157  SALAMAT, IGLESIA NI CRISTO!\n“Dako nga dungog ...
#
# [1158 rows x 1 columns]

# %%
len(df7)
# Out:
# 1158

# %%
orig7 = len(df7)

# %%
label7 = []
for i in range(len(df7)):
  label7.append('df7')
len(label7)
# Out:
# 1158

# %%
df7['text'] = df7['text'].apply(lambda x: x.lower())

# %%
df7['source'] = label7
df7
# Out:
#                                                    text source
# 0     aduna'y pagsaka sa presyo sa lana, epektibo sa...    df7
# 1     motorista, patay human maligsan ang ulo sa 10-...    df7
# 2     9 ka mayor sa negor, nanawagan nga i-postpone ...    df7
# 3     lalaki sa india, nipuyo og dul-an 2 ka tuig sa...    df7
# 4     mao kini ang hulagyway ni president ferdinand ...    df7
# ...                                                 ...    ...
# 1153  senador para\nsa mga trabahador\n“dungan sa pa...    df7
# 1154  kanang card nga malipay kang wala jud nimo nag...    df7
# 1155  nawaan og trabaho\nhataga'g puhunan sa negosyo...    df7
# 1156  loren loves isabela \nsa pagbisita sa mga bolu...    df7
# 1157  salamat, iglesia ni cristo!\n“dako nga dungog ...    df7
#
# [1158 rows x 2 columns]

# %%
df7 = df7.drop_duplicates()
len(df7)
# Out:
# 1156

# %% [markdown]
# #9th Dataset

# %%
ceb_all_data = []

f = open("/content/drive/MyDrive/cbert raw dataset/ceb_all_data.txt", "r")
for line in f:
  ceb_all_data.append(line.strip())
f.close()

# %%
ceb_all_data[0]
# Out:
# 'Akong Higala,1,Akong Higala Gisulat ni: Joan P. Sanchez Gidibuho ni: Justin M. Pono Cebuano Personal Development Ako si Zara. Ako adunay higala. Managsam kami og kinaiya. Pangalan dili nako ipa-ila. Kada adlaw kami mag-uban. Bisan asa kami mag-kuyog. Sa eskwelahan kami mag -uban. Sa pag-uli kami gihapon. Kon walay klase. Bisan asa kami manuroy. Mo-adto kami sa simbahan. Mo-adto kami sa piryahan. Mo-adto kami sa plaza. Mo-adto kami sa zoo. Sa balay kami motabang. Sa among mga maguwang. Ang ginikanan malipay. Sa ilang pag-uli sa balay. Nakaila ka ba niya? Ikaw ba ang akong higala? KATAPUSAN'

# %%
df8 = pd.DataFrame()
df8['text'] = pd.DataFrame(sunstar_dat)
df8
# Out:
#                                                    text
# 0     Gitanggong karon sa Carbon Police Station ang ...
# 1     Dihang wa nakahatag og igong rason nganong kuy...
# 2     Hugot nga gipanghimakak ni Ken nga duna siyay ...
# 3     Matod niya, lima ka tuig na siya nga nagbalik-...
# 4     Nakurat na lang siya nga gi-hold sila diha sa ...
# ...                                                 ...
# 3095  Gani, usa sa mga tubod mobugwak ug yellow nga ...
# 3096  Bugtong ang tubod nga nadiskubrehan sa Alang-a...
# 3097  Nasuta ning mantalaan gi­kan ni Barlam nga nag...
# 3098  Dugang niya nga gipahibalo na sab nila niini a...
# 3099  Sumala ni Barlam nga di mahimong makuhaan ug s...
#
# [3100 rows x 1 columns]

# %%
len(df8)
# Out:
# 3100

# %%
orig8 = len(df8)

# %%
label8 = []
for i in range(len(df8)):
  label8.append('df8')
len(label8)
# Out:
# 3100

# %%
df8['source'] = label8
df8
# Out:
#                                                    text source
# 0     Gitanggong karon sa Carbon Police Station ang ...    df8
# 1     Dihang wa nakahatag og igong rason nganong kuy...    df8
# 2     Hugot nga gipanghimakak ni Ken nga duna siyay ...    df8
# 3     Matod niya, lima ka tuig na siya nga nagbalik-...    df8
# 4     Nakurat na lang siya nga gi-hold sila diha sa ...    df8
# ...                                                 ...    ...
# 3095  Gani, usa sa mga tubod mobugwak ug yellow nga ...    df8
# 3096  Bugtong ang tubod nga nadiskubrehan sa Alang-a...    df8
# 3097  Nasuta ning mantalaan gi­kan ni Barlam nga nag...    df8
# 3098  Dugang niya nga gipahibalo na sab nila niini a...    df8
# 3099  Sumala ni Barlam nga di mahimong makuhaan ug s...    df8
#
# [3100 rows x 2 columns]

# %% [markdown]
# #10th Dataset

# %%
wiki_data = []

f = open("/content/drive/MyDrive/cbert raw dataset/CebWikiContent.txt", "r")
for line in f:
  wiki_data.append(line.strip())
f.close()

# %%
wiki_data[0]
# Out:
# 'ang libre ug gawasnong ensiklopedya Ang Sinugboanong Wikipedya naginusarang ensiklopedya sa Binisaya walay bayad tanawa ang atong copyright Kini ang among damgo Maapodapod sa matag BisayaSugboanon ang usa ka libreng ensiklopedya Ang Mindanao mao ang ikaduhang kinadakang pulo sa Pilipinas Usa kini sa tulo ka mga pundok sa mga pulo sa nasod ang laing duha mao ang Luzon ug ang Kabisayan Ang rehiyon unang naabot sa mga Arabo ug Malay nga mipasabwag sa tinuhoang Islam sa ika13 siglo Misunod ang mga Katsila sa ulahing bahin sa ika16 nga siglo ngadto sa sayong bahin sa ika17 nga siglo Ang mga prayle unang misabwag sa Katolisismo sa maong pulo sa tuig 1622 Kadaghanan sa mga Muslim sa nasod namuyo dinhi Ang uban pang pundok sa mga tawo nga nanimuyo sa Mindanao mao ang mga etnikong pundok sama sa mga Maranao ug Tausug ug ang pundok sa tribung kolektibong gitawag Lumad Dili ang tibuok Mindanao ang nasakop sa mga Muslim Gani ang amihanang Mindanao labi na ang katawhan sa Butuan mga animistiko s
# ...

# %%
len(wiki_data)
# Out:
# 671

# %%
label9 = []
for i in range(len(wiki_data)):
  label9.append('df9')
len(label9)
# Out:
# 671

# %%
df9 = pd.DataFrame()
df9['text'] = pd.DataFrame(wiki_data)
df9
# Out:
#                                                   text
# 0    ang libre ug gawasnong ensiklopedya Ang Sinugb...
# 1    Maayong pagabot sa atong tubaan Kining maong p...
# 2    Maayong pagabot sa Sinugboanong Wikipedya Kon ...
# 3    People on Wikipedia can use this talk page to ...
# 4    Ang elektronika mao ang natad sa pagtuon ug pa...
# ..                                                 ...
# 666  Jollibee mao ang usa ka kananang Pilipinhon ng...
# 667  Jollibee mao ang usa ka kananang Pilipinhon ng...
# 668  Ang Museo Sugbo mao ang lalawiganong museyo sa...
# 669  Ang Homo luzonensis usa ka matang sa pagkawala...
# 670  An Pili Canarium ovatum Lat sarong tanom na na...
#
# [671 rows x 1 columns]

# %%
orig9 = len(df9)

# %%
df9['source'] = label9
df9
# Out:
#                                                   text source
# 0    ang libre ug gawasnong ensiklopedya Ang Sinugb...    df9
# 1    Maayong pagabot sa atong tubaan Kining maong p...    df9
# 2    Maayong pagabot sa Sinugboanong Wikipedya Kon ...    df9
# 3    People on Wikipedia can use this talk page to ...    df9
# 4    Ang elektronika mao ang natad sa pagtuon ug pa...    df9
# ..                                                 ...    ...
# 666  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 667  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 668  Ang Museo Sugbo mao ang lalawiganong museyo sa...    df9
# 669  Ang Homo luzonensis usa ka matang sa pagkawala...    df9
# 670  An Pili Canarium ovatum Lat sarong tanom na na...    df9
#
# [671 rows x 2 columns]

# %% [markdown]
# #Final Dataset

# %%
df_final = pd.DataFrame()
df_final['text'] = pd.concat([df['text'],df1['text'],df2['text'],df3['text'],df4['text'],df5['text'],df6['text'],df7['text'],df8['text'],df9['text']],ignore_index=True)
df_final
# Out:
#                                                      text
# 0                                 'sigurado malipay siya'
# 1         'ang iyang kasingkasing napuno hingpit kalipay'
# 2                                        'pila nag kolor'
# 3                               'makabasa ko og iningles'
# 4                                      'nakita nako mata'
# ...                                                   ...
# 281799  Jollibee mao ang usa ka kananang Pilipinhon ng...
# 281800  Jollibee mao ang usa ka kananang Pilipinhon ng...
# 281801  Ang Museo Sugbo mao ang lalawiganong museyo sa...
# 281802  Ang Homo luzonensis usa ka matang sa pagkawala...
# 281803  An Pili Canarium ovatum Lat sarong tanom na na...
#
# [281804 rows x 1 columns]

# %%
df_final['source'] = pd.concat([df['source'],df1['source'],df2['source'],df3['source'],df4['source'],df5['source'],df6['source'],df7['source'],df8['source'],df9['source']],ignore_index=True)
df_final
# Out:
#                                                      text source
# 0                                 'sigurado malipay siya'     df
# 1         'ang iyang kasingkasing napuno hingpit kalipay'     df
# 2                                        'pila nag kolor'     df
# 3                               'makabasa ko og iningles'     df
# 4                                      'nakita nako mata'     df
# ...                                                   ...    ...
# 281799  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281800  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281801  Ang Museo Sugbo mao ang lalawiganong museyo sa...    df9
# 281802  Ang Homo luzonensis usa ka matang sa pagkawala...    df9
# 281803  An Pili Canarium ovatum Lat sarong tanom na na...    df9
#
# [281804 rows x 2 columns]

# %%
# get the list of unique values and then display the unique values with their corresponding number count

unique_values = df_final['source'].unique()
unique_counts = df_final['source'].value_counts()

for value in unique_values:
  print(f"{value}: {unique_counts[value]}")
# Out:
# df: 103378
# df1: 62076
# df2: 23296
# df3: 1933
# df4: 348
# df5: 82752
# df6: 3094
# df7: 1156
# df8: 3100
# df9: 671

# %%
df_final
# Out:
#                                                      text source
# 0                                 'sigurado malipay siya'     df
# 1         'ang iyang kasingkasing napuno hingpit kalipay'     df
# 2                                        'pila nag kolor'     df
# 3                               'makabasa ko og iningles'     df
# 4                                      'nakita nako mata'     df
# ...                                                   ...    ...
# 281799  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281800  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281801  Ang Museo Sugbo mao ang lalawiganong museyo sa...    df9
# 281802  Ang Homo luzonensis usa ka matang sa pagkawala...    df9
# 281803  An Pili Canarium ovatum Lat sarong tanom na na...    df9
#
# [281804 rows x 2 columns]

# %% [markdown]
# #Cleaning the combined data

# %% [markdown]
# Remove the starting and trailing '

# %%
example = "'hello world tis' a wonderful time.'"
remove_quotes = lambda x: re.sub(r"^'", '', re.sub(r"'$", '', x))

example = "'hello world tis' a wonderful time.'"
print(remove_quotes(example))
# Out:
# hello world tis' a wonderful time.

# %%
df_final['text'] = df_final['text'].apply(lambda x: re.sub(r"^'", '', re.sub(r"'$", '', x)))
df_final.head()
# Out:
#                                             text source
# 0                          sigurado malipay siya     df
# 1  ang iyang kasingkasing napuno hingpit kalipay     df
# 2                                 pila nag kolor     df
# 3                        makabasa ko og iningles     df
# 4                               nakita nako mata     df

# %%
df_final.tail()
# Out:
#                                                      text source
# 281799  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281800  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281801  Ang Museo Sugbo mao ang lalawiganong museyo sa...    df9
# 281802  Ang Homo luzonensis usa ka matang sa pagkawala...    df9
# 281803  An Pili Canarium ovatum Lat sarong tanom na na...    df9

# %%
df_final['text'] = df_final['text'].apply(lambda x: x.replace('\n', ' '))
df_final.tail()
# Out:
#                                                      text source
# 281799  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281800  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281801  Ang Museo Sugbo mao ang lalawiganong museyo sa...    df9
# 281802  Ang Homo luzonensis usa ka matang sa pagkawala...    df9
# 281803  An Pili Canarium ovatum Lat sarong tanom na na...    df9

# %%
df_final.tail(4929)
# Out:
#                                                      text source
# 276875  Dugang niya nga gipahibalo na sab nila niini a...    df6
# 276876  Sumala ni Barlam nga di mahimong makuhaan ug s...    df6
# 276877  aduna'y pagsaka sa presyo sa lana, epektibo sa...    df7
# 276878  motorista, patay human maligsan ang ulo sa 10-...    df7
# 276879  9 ka mayor sa negor, nanawagan nga i-postpone ...    df7
# ...                                                   ...    ...
# 281799  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281800  Jollibee mao ang usa ka kananang Pilipinhon ng...    df9
# 281801  Ang Museo Sugbo mao ang lalawiganong museyo sa...    df9
# 281802  Ang Homo luzonensis usa ka matang sa pagkawala...    df9
# 281803  An Pili Canarium ovatum Lat sarong tanom na na...    df9
#
# [4929 rows x 2 columns]

# %%
#df_final['text'][276877:]

# %%
#df_final['text'][276877:] = df_final['text'][276877:].apply(lambda x: x.lower())
#df_final.tail(4929)

# %%
len(df_final['text'])
# Out:
# 281804

# %%
# prompt: save dataframe into txt file

df_final['text'].to_csv('combined_data_new_nospecial.txt', index=False, header=False)

# %% [markdown]
# ##Distribution of the Datasets

# %%
unique_values = df_final['source'].unique()
unique_counts = df_final['source'].value_counts()

for value in unique_values:
  print(f"{value}: {unique_counts[value]}")
# Out:
# df: 103378
# df1: 62076
# df2: 23296
# df3: 1933
# df4: 348
# df5: 82752
# df6: 3094
# df7: 1156
# df8: 3100
# df9: 671

# %%
len(df_final)
# Out:
# 281804

# %%
# prompt: create a simple table representation which contains 3 columns, first column is the dataframe name like df,df1..., then next is the count and then the last column is the percentage

import pandas as pd
totaldf = 281804

unique_vals = []
for value in unique_counts:
  unique_vals.append(value)
unique_vals.append(281804)


percent_vals = []
for value in unique_counts:
  percent_vals.append((value/totaldf)*100)
percent_vals.append(100)

# Create a DataFrame with the data
data = {'Dataframe': ['df', 'df1', 'df2', 'df3', 'df4', 'df5', 'df6', 'df7', 'df8', 'df9','total'],
        'Orig. Count': [orig0,orig1,orig2,orig3,orig4,orig5,orig6,orig7,orig8,orig9,306262]}

df = pd.DataFrame(data)
df['Count'] = unique_vals
df['Percentage'] = percent_vals
# Create a table representation
table = df.to_string(index=False)

print("Preprocessed Data")
# Print the table
print(table)

df.to_csv('tableDistribution.csv')
# Out:
# Preprocessed Data
# Dataframe  Orig. Count  Count  Percentage
#        df       105252 103378   36.684362
#       df1        62081  82752   29.365091
#       df2        23515  62076   22.028076
#       df3         3984  23296    8.266739
#       df4          608   3100    1.100055
#       df5       102793   3094    1.097926
#       df6         3100   1933    0.685938
#       df7         1158   1156    0.410214
#       df8         3100    671    0.238109
#       df9          671    348    0.123490
#     total       306262 281804  100.000000

# %%
# make the dataframe purely unique with no repeating values

df_final = df_final.drop_duplicates()

# %%
len(df_final)
# Out:
# 281711

# %%
unique_values = df_final['source'].unique()
unique_counts = df_final['source'].value_counts()

for value in unique_values:
  print(f"{value}: {unique_counts[value]}")
# Out:
# df: 103378
# df1: 62076
# df2: 23296
# df3: 1933
# df4: 348
# df5: 82752
# df6: 3094
# df7: 1156
# df8: 3094
# df9: 584

# %%
totaldf = len(df_final)

unique_values = df_final['source'].unique()
unique_counts = df_final['source'].value_counts()

unique_vals = []
for value in unique_counts:
  unique_vals.append(value)
unique_vals.append(totaldf)


percent_vals = []
for value in unique_counts:
  percent_vals.append((value/totaldf)*100)
percent_vals.append(100)

# Create a DataFrame with the data
data = {'Dataframe': ['df', 'df1', 'df2', 'df3', 'df4', 'df5', 'df6', 'df7', 'df8', 'df9','total']}

df = pd.DataFrame(data)
df['Count'] = unique_vals
df['Percentage'] = percent_vals
# Create a table representation
table = df.to_string(index=False)

print("Final Data")
# Print the table
print(table)
# Out:
# Final Data
# Dataframe  Count  Percentage
#        df 103378   36.696473
#       df1  82752   29.374785
#       df2  62076   22.035348
#       df3  23296    8.269468
#       df4   3094    1.098289
#       df5   3094    1.098289
#       df6   1933    0.686164
#       df7   1156    0.410350
#       df8    584    0.207305
#       df9    348    0.123531
#     total 281711  100.000000

# %%
df_final['text'].to_csv('combined_norepeat_nospecial.txt',index=False,header=False)

# %% [markdown]
# #Lowercase all text for uncased model

# %%
df_final['text'] = df_final['text'].apply(lambda x: x.lower())
df_final.head(5)
# Out:
# <ipython-input-101-b58edf2f3a56>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['text'] = df_final['text'].apply(lambda x: x.lower())
#                                             text source
# 0                          sigurado malipay siya     df
# 1  ang iyang kasingkasing napuno hingpit kalipay     df
# 2                                 pila nag kolor     df
# 3                        makabasa ko og iningles     df
# 4                               nakita nako mata     df

# %%
df_final['text'].to_csv('combined_uncased.txt',index=False,header=False)
